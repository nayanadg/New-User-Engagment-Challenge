# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
df = pd.read_csv("dataset.csv")

# %%
df.drop("Unnamed: 0", axis = 1, inplace=True)

# %%
df
# Out:
#                     User_ID  Personal  Theme  comment_day  Participant Type  \
# 0       ID_000H9XOP_Month_5      -1.0   -1.0          0.0               0.0
# 1       ID_003YJHQA_Month_4      -1.0   -1.0          0.0               0.0
# 2       ID_004UKSJV_Month_1      -1.0   -1.0          0.0               0.0
# 3      ID_004UKSJV_Month_12      -1.0   -1.0          0.0               0.0
# 4       ID_008D2J6C_Month_1      -1.0   -1.0          0.0               0.0
# ...                     ...       ...    ...          ...               ...
# 17386   ID_ZZMHNLNT_Month_4      -1.0   -1.0          0.0               0.0
# 17387   ID_ZZQK0LU6_Month_3      -1.0   -1.0          0.0               1.0
# 17388   ID_ZZUNZJ2U_Month_2      -1.0   -1.0          0.0               0.0
# 17389   ID_ZZVM2KO7_Month_4      -1.0   -1.0          0.0               0.0
# 17390   ID_ZZVUJ45W_Month_3      -1.0   -1.0          0.0               1.0
#
# ...

# %%
df["Month"] = df["User_ID"].str[18:]
df["Month"] = pd.to_numeric(df["Month"])

# %%
df["Month"].unique()
# Out:
# array([ 5,  4,  1, 12,  2,  3, 11], dtype=int64)

# %%
df_train = df[(df["Month"]== 1) | (df["Month"]== 2) | (df["Month"]== 3) | (df["Month"]== 4) | (df["Month"]== 11) | (df["Month"]== 12)]

# %%
df_train["Month"].unique()
# Out:
# array([ 4,  1, 12,  2,  3, 11], dtype=int64)

# %%
df_train.shape
# Out:
# (14906, 53)

# %%
df_test = df[df["Month"]== 5]

# %%
df_test["Month"].unique()
# Out:
# array([5], dtype=int64)

# %%
df_test.shape
# Out:
# (2485, 53)

# %% [markdown]
# ## CLUSTERING

# %%
from sklearn.cluster import KMeans

# %%
df_train.drop("User_ID", axis=1, inplace=True)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14906 entries, 1 to 17390
# Data columns (total 52 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Personal                              14906 non-null  float64
#  1   Theme                                 14906 non-null  float64
#  2   comment_day                           14906 non-null  float64
#  3   Participant Type                      14906 non-null  float64
#  4   Successful Submission Count           14906 non-null  int64
#  5   competition_enrollment_day            14906 non-null  float64
#  6   FeatureA                              14906 non-null  object
#  7   FeatureB                              14906 non-null  object
#  8   FeatureC                              14906 non-null  float64
#  9   FeatureD                              14906 non-null  float64
# ...

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2).fit(df_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_808/749454513.py in <module>
#       1 from sklearn.decomposition import PCA
# ----> 2 pca = PCA(n_components=2).fit(df_train)
#
# ~\AppData\Roaming\Python\Python39\site-packages\sklearn\decomposition\_pca.py in fit(self, X, y)
#     406         )
#     407
# --> 408         self._fit(X)
#     409         return self
#     410
#
# ~\AppData\Roaming\Python\Python39\site-packages\sklearn\decomposition\_pca.py in _fit(self, X)
#     454             )
#     455
# --> 456         X = self._validate_data(
#     457             X, dtype=[np.float64, np.float32], ensure_2d=True, copy=self.copy
#     458         )
#
# ~\AppData\Roaming\Python\Python39\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
# ...

# %%
kmeans = KMeans(init='k-means++', n_clusters=2, n_init=2)

# %%
kmeans.fit(X)

# %%
P = kmeans.predict(X)

# %%
colors = list(map(lambda x: '#3b4cc0' if x == 1 else '#b40426', P))
plt.scatter(X[:,0], X[:,1], c=colors, marker="o", picker=True)
plt.title('Two clusters of data')
plt.xlabel('Temperature yesterday')
plt.ylabel('Temperature today')
plt.show()
